# %%
import urllib.request
import json 

client_id = "dVKvci2Xi195XkwP48qU"
client_secret = "OA6Iadda_h"
query = "천문"
encText = urllib.parse.quote("query")
num = 100
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display="+str(num)
 
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    datalist = json.loads(response_body)
    count = 1
    print('['+query+'에 대한 포털사이트 블로그 글]')
    for data in datalist['items'] :
        print(str(count) + " : "  +data['title'])
        print("["+data['description'] +"]")
        count+=1
else:
    print("Error Code:" + rescode)
# Out:
# [천문에 대한 포털사이트 블로그 글]
# 1 : VLOOKUP함수 한계 넘어서기 &lt; INDEX&amp;MATCH&lt;&lt;&lt;&lt;&lt; <b>QUERY</b>함수...
# [구글시트에서는 <b>QUERY</b>라는 함수를 지원함으로써, 그 활용폭이 엄청나게 늘어나게 된다. 보통 SQL... 벗어나 <b>QUERY</b>함수를 사용하는 기본 샘플을 넣었다. <b>QUERY</b>함수의 경우 조건 옵션이 너무 많아, 여기에서는... ]
# 2 : 웹퍼블리셔/웹디자인/HTLM/CSS/JavaScript/J-<b>Query</b>
# [코딩: HTML, CSS, J-<b>Query</b>를 활용하여 포토샵으로 만든 이미지를 웹상에서 보여지게 개발을... J-<b>Query</b> 자, 그럼 순서대로 알아볼까요? 1. HTML5 ▼ ①. HTML5란? · 쉽게말해서 웹을 만드는 첫 시작, 뼈대를 만드는... ]
# 3 : 17 데이타베이스 - 2019.1223.017.오전-Sub <b>Query</b>
# [Sub <b>Query</b> (서브쿼리) *조회문법(syntax) SELECT {* | [DISTINCT] 컬럼명, 컬럼명 [as] alias,..., t.컬럼명} FROM 테이블명 alias, [WHERE 조건] (서브쿼리 select 컬럼명, 컬럼명,...) from 테이블명... ]
# 4 : TABLESPACE 사용량 조회 (TABLESPACE Usage Check) <b>Query</b>
# [TABLESPACE 별 전체용량, 사용량/비율, 잔여량/비율 등을 조회할 경우 유용항 <b>Query</b> 입니다. TABLESPACE 용량을 모두 사용한 경우, Database 서버 콘솔로 접속해서... ]
# 5 : 자바스크립트 이벤트 / 제이쿼리(j-<b>Query</b>) / JSON / a-jax...
# [(j-<b>Query</b>) / JSON / a-jax이다. 프로젝트하면서 정말 자주 다루게 되는 내용들... 특히 a-jax... (j-<b>Query</b>) 간단 정리 * j-<b>Query</b> $(document).ready(function(){...});= window.onload&lt;기본문법&gt;$('h1').css('color... ]
# 6 : SQLite 쿼리 실행 계획을 보기 위해서 explain <b>query</b> plan...
# [Explain <b>Query</b> Plan을 사용하니..간단하기는 하지만..가장 원했던 항목이 보이니..결국.. 이것부터... 인덱스를 스캔했는지 Seek 했는지 안나온다..ㅠ,.ㅠ Explain <b>Query</b> Plan으로 하니.. 한줄만 나오지만..... ]
# 7 : CRUD] CREATE, SELECT, INSERT, UPDATE, DELETE <b>Query</b> 작성
# [일은 <b>QUERY</b>라고 한다. 본인은 skku_db라는 이름으로 스키마 하나를 만들었다. 여기서 Table을... Apply 누르면 생성되는데 다음과 같이 create와 관련된 <b>query</b> 함수들이 자동으로 만들어진다.... ]
# 8 : MySQL <b>Query</b> Browser 1.2.17 에서 테이블 생성시 한글 입력...
# [MySQL <b>Query</b> Browser 1.2.17 에서 &quot;Create New Table&quot; 메뉴를 클릭한 후, 아래와 같이 입력하여서 테이블을 생성하였습니다. 위에서 생성된 테이블에 &quot;Edit&quot; 버튼을 클릭한 후, 아래와... ]
# 9 : FlashBack <b>Query</b> (AS OF TIMESTEMP) 과거 데이터 조회
# [이전의 어느 시점까지의 언두(UNDO)정보를 보유하여 Flashback <b>Query</b>를 수행할것인지 UNDO_RETENTION 파라미터를 설정해야 한다. - ALTER SYSTEM SET UNDO_RETENTION=1200 출처: https... ]
# 10 : [PWC] Python으로 PowerCenter의 <b>Query</b> Base 테이블명 추출
# [ATTR_ID = 1 -- // SQ의 <b>QUERY</b> BASE 인것 AND ATTR.ATTR_VALUE IS NOT NULL AND LINE_NO = 1 ORDER... ATTR_ID = 1 -- // SQ의 <b>QUERY</b> BASE 인것 AND ATTR.ATTR_VALUE IS NOT NULL AND SUBJ.SUBJ_NAME... ]
# 11 : QPI(<b>Query</b> Performance Insights) 라이브러리를 사용하여...
# [QPI(<b>Query</b> Performance Insights) 라이브러리를 사용하여 Azure SQL Managed Instance의 로그쓰기... QPI 라이브러리는 <b>Query</b> Store 보기에 의존하기 때문에 SQL Server 2016이상, Azure SQL 에서... ]
# 12 : 조건검색 함수 정리, VLOOKUP, INDEX(MATCH), DGET, FILTER, <b>QUERY</b>...
# [<b>QUERY</b> 엑셀도 버전이 바뀔수록 구글시트에서 지원하는 함수를 적용하는듯… 이 포스트 작성시점... 365 <b>QUERY</b>는 EXCEL 2007부터 있긴 했지만 고급 사용자용으로 구글시트<b>QUERY</b>와 차이가 있음. 참고로... ]
# 13 : 데이터 프레임 내 특정 글자 포함 유무 확인하기: <b>query</b>() 활용
# [blog.naver.com 해당 글자와 일치하는 데이터 전체를 불러오고 싶을 때, <b>query</b>() &gt; weight_loss.<b>query</b>('Month == &quot;Jan&quot;') # Month 열에 Jan 을 포함하고 있는 데이터들의 전체를 보고싶을 때는 <b>query</b>()를... ]
# 14 : (Joining <b>query</b>)를 이용해서 데이터 분석하기 &gt; QueryDSL...
# [optimize <b>query</b> response. In this case it is the DBMS software's responsibility to ensure that any... (Joining <b>query</b>)를 수행하는 방법이 있습니다. (분산 환경에 최적화있게 조인을 다시... ]
# 15 : Document Expansion by <b>Query</b> Prediction
# [https://arxiv.org/pdf/1904.08375.pdf 새로운 <b>query</b> prediction model 에 대한 소개는 아니고 그냥 기본 모델을 사용해서 <b>query</b> prediction을 했을 때, 얼마나 성능이 개선되는가 살펴보는 실험... ]
# 16 : 18 데이타베이스 - 2019.1224.018.오전-다중행 SUB <b>Query</b>
# [다중행 SUB <b>Query</b> *DML(DATA Manipulation Language)- 데이터조작어 -Insert(입력) -Select(조회)... --다중행 SUB <b>Query</b> --다중행 서브쿼리를 사용할 때에는 서브쿼리 앞에 연산자를... ]
# 17 : 쿼리 튜닝, <b>Query</b> Tuning
# [쿼리 튜닝, <b>Query</b> Tuning 쿼리 튜닝의 시작은 대개 최초 작성자의 의도 파악후 조정하는 것이다. 기 작성된 <b>Query</b>를 보고 난 뒤 잘 못 작성된 쿼리나 불필요한 서브 쿼리가 있는 경우 튜닝을 하는 것이다.... ]
# 18 : (mongodb debug #6) mtools for finding slow <b>query</b>
# [mtools에서 <b>query</b>의 performance를 검사하기 위해서 사용하는 툴은 아래 세가지가... about <b>query</b> patterns --sort {namespace,pattern,count,min,max,mean,95%,sum} --restarts outputs... ]
# 19 : KIbana에서 구문에 대한 <b>Query</b> Profile 해보기...
# [<b>Query</b> Profile 창에... 사용된 시간이 나타난다. &quot;&gt;&quot; 모양을 누르면.. 아래로 펴지면서 상세한 내용이 나타난다. 구문이 한개 밖에 없어서... 자세하지 않지만.. 단계가 많아지면.. 여러가지가 나타나게 된다.... ]
# 20 : 범위 쿼리 - Range <b>Query</b>
# [Input GET phones/_search { &quot;<b>query</b>&quot;: { &quot;range&quot;: { &quot;price&quot;: { &quot;gte&quot;: 700, &quot;lte&quot;: 900 } } } } Output... *날짜검색 Input GET phones/_search { &quot;<b>query</b>&quot;: { &quot;range&quot;: { &quot;date&quot;: { &quot;gt&quot;: &quot;2016-01-01&quot; } } } } Output... ]
# 21 : [SQL] 서브쿼리(Sub-<b>Query</b>)
# [Sub-<b>Query</b> SQL 문장 안에 또 다른 SELECT문. 1. 연관성 없는 서브쿼리 = 일반적인 서브쿼리 : 메인쿼리와 연관성이 없는 쿼리 : 안쪽(아래쪽) 쿼리부터 실행 후 바깥쪽... ]
# 22 : Wargame.kr Challenge - login filtering (PHP, MySQL <b>query</b>)
# [* 필요한 기술(지식) : PHP, MySQL <b>query</b> login filtering 문제입니다. 문제를 보니 계정을 가지고... 그리고 mysql_<b>query</b> 함수를 통해 escape 처리된 id 값과 md5 해시된 ps 값이 테이블에 있는지 확인하고... ]
# 23 : Why is NGINX is ignoring my <b>query</b> strings?
# [http://localhost:8484/api/messages?to=3&amp;from=1 위의 요청 시 <b>Query</b> String Parameters에는 to:3, from:1 값이 있으나 실제로 소스에서 GET Data를 찍었을 경우 값이 없는 경우가... ]
# 24 : (2) - REGEXMATCH, REGEXEXTRACT, REGEXREPLACE + <b>QUERY</b>,G suite
# [<b>QUERY</b>함수에서 텍스트 검색으로 필터링하여 자료 추출하기 'LIKE, CONTAINS, MATCHES' 마지막으로 <b>QUERY</b>함수 옵션에서도 비슷하게 사용하는 기능이 있어, 추가설명을 하고자 한다. 1) e와 e사이에... ]
# 25 : [JPA] @<b>Query</b>와 @Modifying
# [@<b>Query</b>는 기본적으로 'select' 구문만을 지원하지만 @Modifying을 이용해서 DML(insert... public interface PDSBoardRepository extends CrudRepository&lt;PDSBoard, Long&gt; { @Modifying @<b>Query</b>... ]
# 26 : 2개 이상의 조건과 일치하는 데이터 전체 불러오기 <b>query</b> 활용
# [1개의 조건과 일치하는 데이터 불러오기 01 &gt; weight_loss.<b>query</b>('Month == &quot;Jan&quot;') # Month 열의 값이... &gt; weight_loss.<b>query</b>('Week == &quot;Week 4&quot;') # Week 열에서 Week 4와 일치하는 데이터만 불러오기 2개의... ]
# 27 : JMP <b>Query</b> Builder를 통한 MariaDB 데이터베이스 데이터...
# [하지만 엔지니어 중에서 SQL <b>Query</b>를 능숙하게 다루는 사람이 얼마나 있을까요? 후후 저희도 마찬가지입니다. 하지만 저희는 다행히 JMP가 제공하는 <b>Query</b> Builder가 있습니다. 전문 SI 엔지니어가... ]
# 28 : SQL튜닝 - 게시판 구현시 페이징 <b>query</b> 예시
# [DB 프로세스가 최소한의 일만 하도록 하는 효율적인 <b>Query</b> 작성이 최고의 SQL 튜닝이다 -- 변경전 페이징 쿼리 -- 게시글만큼 NL조인이 발생, function call발생, 서브쿼리 발생함 select... ]
# 29 : Revising the Select <b>Query</b> I
# [#해커랭크 #hackerrank #mysql 리트코드가 무료인줄 알았는데 아니었네요 ㅜㅜ <b>Query</b> all columns for all American cities in CITY with populations larger than 100000. The... ]
# 30 : [SQL] <b>Query</b>문 이론 (1-10)
# [<b>Query</b> 문 데이터를 검색하는 언어 <b>Query</b>는 데이터를 검색하는 언어이다. 검색은 “Select”으로 시작한다. Select ename, sal Form emp; Select 뒤에 검색하고자하는 컬럼을 입력 다음줄에는 From... ]
# 31 : [MySQL] MySQL <b>Query</b> Browser 시작시 윈도우 위치 수정하는...
# [듀얼 모니터 환경에서 MySQL <b>Query</b> Browser 를 2번째 모니터에 보여지도록 설정한 후, 종료하면 하나의 모니터만 사용하는 환경에서 MySQL <b>Query</b> Browser 실행시 2번째 모니터 위치에... ]
# 32 : [Shell] Top <b>Query</b> check (by dba.sql_history)
# [sh 20190107 (<b>Query</b> StartDate) ####################################################### Logfile... long <b>query</b> psql -AXtc &quot; select event_time, user_name, database_name, gp_session_id, gp... ]
# 33 : 5.2 Bool 복합 쿼리 - Bool <b>Query</b>
# [앞의 <b>query</b>_string 쿼리는 여러 조건을 조합하기에는 용이한 문법이지만 옵션이... Input GET my_index/_search { &quot;<b>query</b>&quot;: { &quot;bool&quot;: { &quot;must&quot;: [ { &quot;match&quot;: { &quot;message&quot;: &quot;quick&quot; } }, { &quot;match_phrase... ]
# 34 : MYSQL 집계합수, Group <b>query</b> 사용법
# [https://galid1.tistory.com/609 Mysql - 집계함수와(sum, count) Group <b>query</b> 사용법 (GROUP BY, HAVING) mysql group by를 쓰는 곳과 사용법 이번 시간에는 Group <b>query</b> 라고 불리우는... ]
# 35 : 드롭다운메뉴(Drop-down Menu) 구성 - INDIRECT,<b>QUERY</b>,FILTER
# [<b>QUERY</b> 함수를 사용하여 종속된 2중 드롭다운메뉴 구성하기 종속된 2중 드롭다운메뉴 구성에 있어, 구글시트에서는 <b>QUERY</b>함수를 이용하여 구성 할 수도 있다. 사용할 함수의 선택은 개인취향이다. 아래처럼... ]
# 36 : [CosmosDB] Scalar Expression <b>Query</b>, Built-in Operator
# [[<b>Query</b> Explorer]를 선택해서 기본적인 쿼리를 테스트 해 볼 수 있다. 실행을 원하는 쿼리 부분을 마우스로 드래그하여 선택하고 [Run <b>Query</b>]를 클릭하여... ]
# 37 : [DB Tool] <b>Query</b> Box
# [- 국내 소프트웨어 업체에서 만든 데이터베이스 툴인 <b>Query</b> Box. 회사에서 쓰는 걸 본 적이... 데이터베이스 www.querybox.com - 아래는 <b>Query</b> Box 실행화면. SQL Developer 보다 UI 도 깔끔하고 좋다. 헠헠]
# 38 : [Spring] Data <b>Query</b> Method
# [1) 좋아요 공감 공유하기 글 요소 구독하기 초보 프로그래머의 하루 ' Development &gt; Spring ' 카테고리의 다른 글 [Spring] Data <b>Query</b> Method (0) 2017.12.15 Spring... ]
# 39 : Slow <b>Query</b> 식별 및 수정
# [a <b>query</b> waits on a lock - log_temp_files = 0 # log temporary files equal or larger # than the... bad <b>Query</b> Plan * l사용자를 disconnect하기 SELECT pg_terminate_backend(pid) FROM pg_stat... ]
# 40 : [PWC] Python 으로 pwc meta <b>query</b>, pre, post sql Export
# [SQ <b>Query</b>, Pre Post Contents # - parameter (V_SUBJ_NAME, V_MAPPING_NAME, V_INSTANCE_ID, V... SQ <b>Query</b>, Pre Post Contents # - parameter (V_SUBJ_NAME, V_MAPPING_NAME, V_INSTANCE_ID, V... ]
# 41 : [다수 테이블 개별 Count 및 소계 <b>Query</b> Excel 수식]
# [위의 <b>Query</b> 를 생성하는 Excel 수식은 아래와 같다. =CONCATENATE(IF(RIGHT(TRIM(A1),2)=&quot;01&quot;, &quot;SELECT DECODE(GROUPING(TBL_ID), 1, '총건수', TBL_ID) AS TBL_ID, SUM(CNT) AS CNT FROM... ]
# 42 : [AWS] CloudSearch Structured <b>Query</b> 실행 방법
# [이를 AWS CloudSearch 에서는 Structured <b>Query</b> 라고 한다. 게시판과 같은 데이터의 경우... 검색 방법 TEXT 대상으로한 Range 검색을 위해서는 <b>Query</b> Parser를 Structured로 변경하고... ]
# 43 : Revising the Select <b>Query</b> II
# [#mysql #hackerrank <b>Query</b> the names of all American cities in CITY with populations larger than 120000. The CountryCode for America is USA. Input Format The CITY table is described as... ]
# 44 : [CodeIgniter] 2. DB 연동(+Multi <b>Query</b>)
# [$<b>query</b>_builder = FALSE; // SP 만 사용할 예정이라 쿼리빌더는 비활성화 $db... Multi_<b>Query</b> 설정 (MySQL, MariaDB 전용) system/database/drivers/mysqli_driver.php 에서 _execute... ]
# 45 : [shell] 3.2.stat_<b>query</b>.sh
# [stat_<b>query</b>.sh 20190107(<b>Query</b> StartDate) ####################################################### SHELL_NM=$0 CURDIR=`pwd` LOGDIR=$CURDIR&quot;/&quot;log LOGFILE=$LOGDIR&quot;/&quot;$SHELL_NM&quot;.log&quot; mkdir -p... ]
# 46 : DBX Search,lookup/ Oracle <b>query</b> sample
# [ORACLE_SEARCH_<b>QUERY</b>_SAMPLE index=_internal | head 1 | eval FIRM_NO=&quot;077&quot; | eval USER_NAME... Search <b>Query</b> Sample | dbxquery <b>query</b>=&quot;select USER_NAME,PERSON_PARTY_ID from FND_USER where USER... ]
# 47 : 풀 텍스트 쿼리 - Full Text <b>Query</b>
# [match _all 모든 도큐먼트 검색 Input GET my_index/_search { &quot;<b>query</b>&quot;: { &quot;match_all&quot;: {} } }... Input GET my_index/_search { &quot;<b>query</b>&quot;: { &quot;match&quot;: { &quot;message&quot;: &quot;dog&quot; } } } Output } &quot;took&quot; : 2... ]
# 48 : Beyond EXPLAIN: <b>Query</b> Optimization From Theory To Code
# [html PGCon2016: Beyond EXPLAIN: <b>Query</b> Optimization From Theory To Code Speakers Ryoji... EXPLAIN: <b>Query</b> Optimization From Theory To Code EXPLAIN is too much explained. Let's... www.pgcon.... ]
# 49 : where=image&amp;sm=tab_jum&amp;<b>query</b>=%EC%97%98%EC%8A%A4%EC%95...
# [https://search.naver.com/search.naver?where=image&amp;sm=tab_jum&amp;<b>query</b>=%EC%97%98%EC%8A%A4%EC%95%84%ED%8C%8C%ED%8A%B8#imgId=blog16571598%7C37%7C130123712731_1023811591&amp;vType=rollout 엘스아파트... ]
# 50 : [Dynamics CRM SDK] <b>Query</b> Expression
# [<b>Query</b> Expression은 C# 을 이용하여 CRM의 데이터들을 조회할 수 생성자... var <b>query</b> = new QueryExpression(&quot;contact&quot;){ ColumnSet = new ColumnSet(true), //모든 컬럼 가져오기 }... ]
# 51 : JMP <b>Query</b> Builder를 적용한 SQLite, MariaDB 교육 및...
# [JMP의 <b>Query</b> Builder를 적용한 SQLite 및 MariaDB 데이터베이스에 대한 데이터 전처리 및 통계분석에... 아래 이미지는 JMP가 제공하는 <b>Query</b> Builder를 적용하여 SQLite 데이터베이스에 연결하여 <b>Query</b>... ]
# 52 : 데이터베이스(DataBase)와 SQL(Structured <b>Query</b> Language)
# [(structured <b>query</b> language,쿼리문) 은 데이터베이스에서 데이터를 정의(Definition), 조작(Manipulation), 제어(Control) 하기 위해 사용하는 언어입니다. 목적에 따라 크게 세 가지로 구분됩니다. 1.DDL(Data... ]
# 53 : [Python] Oracle <b>Query</b> Parameter 사용하기
# [description[i][0]) # sub <b>query</b> result rows = cur.fetchall() cur.close() con.close() now = datetime.datetime.now() nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S') print... ]
# 54 : MSSQL 취약점 진단 : SQL <b>Query</b>
# [EXEC sp_helplogins; exec sp_helpuser; EXEC sp_helpsrvrolemember 'sysadmin'; EXEC sp_helpsrvrolemember; SELECT count(name) FROM sys.sql_logins WHERE password_hash is null AND name='sa... ]
# 55 : [MySQL] pivot <b>query</b> (like excel)
# [mysql&gt; mysql_pivot_<b>query</b>; +-----------+--------+--------+--------+--------+ | hostname... Pivot <b>Query</b> 그렇게 pivot 기능을 위한 쿼리입니다. SET @NOWDATE = LEFT(NOW(), 10); SET... ]
# 56 : [AWS] Athena <b>Query</b> with Lambda
# [특히 2019 AWS re:Invent 에서 나온 Ferderate <b>Query</b>도 Athena 를 통해 여러 데이터... S3_OUTPUT = 's3://your_athena_<b>query</b>_output_backet_name' S3_BUCKET = 'your_athena_<b>query</b>_output... ]
# 57 : 회사이야기 #1 : AWS RDS에 slow <b>query</b> log 남기기
# [slow <b>query</b>를 사용해보기로 했다. (이미지 리사이징이 되지 않아 00MB의 사진을 다운받느라 느린... 일단 slow_<b>query</b>_log에 대한 default 값이 0 (사용안함)이기 때문에 이 값을 1로 바꿔준다. 하지만 이... ]
# 58 : [Excel 2013] 엑셀  2013 파워 쿼리 (Power <b>Query</b>)
# [[Excel 2013] 엑셀 2013 파워 쿼리 (Power <b>Query</b>) 엑셀 2010부터 사용이 가능한 파워 쿼리에 대해서... 마우스 오른쪽 클릭하고 Edit을 누르면 <b>Query</b> Editor 으로 연결이 된다. <b>Query</b> Editor를 통해서... ]
# 59 : <b>Query</b> DSL-1
# [##<b>Query</b> String <b>Query</b> ##URL의 q 파라메터를 이용해서 검색을 수행하는 것을 설명했습니다. URL검색에 사용하는 루씬의 검색 문법을 본문 검색에 이용하고... ]
# 60 : AWS DynamoDB in Python (Boto3) - #4. <b>Query</b> &amp; Scan
# [위한 <b>Query</b> &amp; Scan에 대해서 다루어보도록 하겠습니다. 모든 내용은 AWS의 Boto3... <b>Query</b> &amp; Scan 두 가지 모두 DynamoDB의 항목 호출을 위한 기능이지만, 사용 용도는 약간 차이가... ]
# 61 : <b>Query</b> DSL
# [##########<b>query</b> test POST _bulk { &quot;index&quot; : { &quot;_index&quot; : &quot;test_by&quot;, &quot;_type&quot; : &quot;_doc&quot;, &quot;_id... All <b>Query</b> GET test_by/_search { &quot;<b>query</b>&quot;: { &quot;match_all&quot;: {} } } { &quot;took&quot; : 2, &quot;timed_out... ]
# 62 : mssql 프로파일러(profiler) 역활 <b>query</b>  - 악성 쿼리...
# [가장 처음에 의심해볼만한것이 바로 악성쿼리 즉 부하가 높은 <b>query</b> 를 의심했습니다. 백신등의 다른... 돌아가는 <b>query</b>가 문제가 생길수 있는데요. mssql 이면 프로파일러로 걸어 놓고 나중에 문제되는걸... ]
# 63 : CQL (Continuous <b>Query</b> Language)
# [CQL (Continuous <b>Query</b> Language) 1. CQL (Continuous <b>Query</b> Language)의 개요 1-1. 정의 - SQL '99를 기반으로 한 ANSI 표준언어로써, 연속적인 스트림 데이터를 처리하기 위한 최상의 개발 언어 1-2. 주요기능 1)... ]
# 64 : SAS sql구문 심화 sub-<b>query</b>(SQL/Sub-<b>Query</b>/subquery...
# [안녕하세요 이번 강의에서는 SQL의 더 고급사용법인 sub <b>query</b>에 대해서 배워보겠습니다. Sub-<b>query</b> 를 이용하게 되면 가장 큰 장점이 바로 문장수행의 간결성입니다. sub-<b>query</b>를 얼마나 잘... ]
# 65 : CSS3 반응형 웹? #Media <b>Query</b> [미디어 쿼리]
# [CSS3 반응형 웹 만들기 Media <b>Query</b> [미디어 쿼리] 이번에 해볼 것은 Media <b>Query</b> 라는 것입니다. 처음 들어 볼 때는 Media <b>Query</b>라는 글자 자체도 어려워 보이고 왠지 어려울 거 같고 그런데 막상... ]
# 66 : Kafka Streams 로 Interactive <b>Query</b> 를 위한 초기화
# [b Kafka Streams 로 Interactive <b>Query</b> 를 위한 초기화 본문 카테고리 없음 Kafka Streams 로 Interactive <b>Query</b> 를 위한 초기화 dev.bistro 2019. 10. 31. 18:27 카프카 스트림은으로... ]
# 67 : SQL Server 2016 미리보기: <b>Query</b> Store
# [이번 포스팅에서는 <b>Query</b> Store 에 대해서 얘기해볼까 합니다. SQL Server는 쿼리를 실행하기 위해서... 바로 <b>Query</b> Store를 통해서요. ^^ ※ 본 내용은 SQL Server 2016 CTP 2.4 기준으로 작성되었으며, 이후 CTP나 RTM... ]
# 68 : <b>Query</b> Routing을 통한 On-Demand Mart 구성
# [(<b>query</b>, mid-<b>query</b>, big-<b>query</b> branch) 2. 실시간으로 hdfs에서 생성한 데이터를 mart에 적재하여 mart에 데이터가 있는 척! 3. 모든 req/res는 REST API 기반 micro 서비스 구조로 처리! (다른 서비스를 만들 때 또... ]
# 69 : PostgreSQL DBMS 관리를 위한 <b>Query</b> 몇가지
# [pg_cancel_backend는 해당 PID만 중지시키려고 하고, pg_terminate_backend는 해당 PID와 연계된 모든 상위 <b>Query</b> Process를 모두 중지시킵니다. 따라서 pg_cancel_backend로 해당 작업이 중지되는지... ]
# 70 : MySQL/MariaDB 아키텍처- 쿼리 캐시(<b>Query</b> Cache)
# [MySQL/MariaDB 아키텍처 – 쿼리 캐시(<b>Query</b> Cache) Version : Mariadb 5.5.4.2-WinX64 MySQL / MariaDB 쿼리 캐시(<b>Query</b> Cache)는 타 DBMS에는 없는 기능을 적절히 설정만 잘한다면 상당한 성능 향상 효과를 얻을 수... ]
# 71 : SAP <b>Query</b> report로 Master data 간단 조회 report 구현
# [SAP <b>Query</b> report로 Master data 간단 조회 report 구현 프로젝 진행시 GL Master 조회... SAP <b>Query</b> report로 간단히 조회할수 있도록 GL, Vendor, Customer 등 마스터데이터 조회 리포트를 구현해 주고... ]
# 72 : TestComplete 에서 MySQL <b>Query</b> 방법
# [TestComplete에서 MySQL <b>Query</b> 방법입니다. 일단 주의해야 하는 부분은 TestComplete의 아키텍쳐가 32비트라는 점입니다. 따라서 ODBC Driver 32비트를 설치하여야 합니다. 하지만... ]
# 73 : Sys.dm_exec_<b>query</b>_plan 에서 <b>query</b>_plan 컬럼의 NULL 값...
# [Sys.dm_exec_<b>query</b>_plan 에서 <b>query</b>_plan 컬럼의 NULL 값 반환 Version : SQL Server 2008, 2008 R2, 2012, 2014, 2016 SQL Server에서 쿼리 계획을 확인하기 위한 방법에는 DMV를 사용하는 방법이 있다.... ]
# 74 : [안드로이드] android 내부 DB와 <b>query</b> 문을 이용한 메모장...
# [안드로이드 내부에 있는 DB와 기본적인 <b>Query</b> 문을 이용해서 메모를 저장하고 다시 불러올 수 있으며... 일단 안드로이드 내부 DB와 <b>Query</b> 문을 써서 데이터를 읽고 쓰며, 거기에 부가적인 기능으로... ]
# 75 : 12. 부속질의(Sub-<b>query</b>)
# [이 몸뚱아리를 어떻게 다시 부지런하게 만들어야 할지...에효 여튼, 오늘은 지난번에 말씀 드렸다시피 부속질의(Sub-<b>query</b>)에 대해 알아볼게요 :) 부속질의(Sub-<b>query</b>)는 하나의 SQL문 안에 다른... ]
# 76 : Infochimps <b>Query</b> API is Bananas - ReadWrite
# [But did you know that <b>Query</b> API access is free to noodle with on the Baboon tier? Let’s explore a bit more and see what a <b>Query</b> API Baboon subscription can monkey with for free.... ]
# 77 : '<b>query</b>' 태그의 글 목록
# [Pocket <b>Query</b> / Bookmark / Find Caches Along a Route / Set up Notifications 이 핵심적인 제공 서비스인데요 그 중에서도 제일 유용한 기능중에 하나인 Pocket <b>Query</b>(이하 PQ)기능입니다. 다른 추가적인 기능등... ]
# 78 : 오라클 기본개념, 데이터베이스 언어, <b>Query</b>
# [데이터베이스 언어 : SQL (Structured <b>Query</b> Language) --&gt; 대소문자 구별이 없다. --&gt; 문장의... 3) <b>Query</b> : select (데이터 조회) 4) DCL (Database Control Language) : grant (권한 설정) : revoke... ]
# 79 : SQL 자주쓰는 쿼리 _ ALTER <b>Query</b> 편!! # 2
# [ALTER <b>QUERY</b> 는 이정도로 해야겠네요... 뭐 여러가지 있지만 이정도만 알고있어도 사용하는덴 큰... 27 SQL 자주쓰는 쿼리 _ ALTER <b>Query</b> 편!! # 2 (6) 2011.01.14 [안드로이드] 에뮬레이터에 한글키보드를... ]
# 80 : SQL 자주쓰는 쿼리 _ ALTER <b>Query</b> 편!! # 1
# [CASE <b>Query</b> 편!! [ 조건문 쿼리 ] (7) 2010.02.07 SQL 자주쓰는 쿼리 !! 문자열 조작 함수 편 ! (0) 2010.02.05 SQL 자주쓰는 쿼리 _ ALTER <b>Query</b> 편!! # 1 (0) 2010.02.04 SQL 자주쓰는 쿼리 _ SHOW <b>Query</b> 편!! (0) 2010.02.... ]
# 81 : [#19] 워드프레스 쿼리 함수 3인방 <b>query</b>_posts()
# [이럴 경우를 대비에서 워드프레서에서는 <b>query</b>_posts() , WP_<b>Query</b>() , get_posts() 의 3가지 함수를 제공하고 있습니다. <b>query</b>_posts() 는 하나의 루프를 사용하면서 동시에 반환되는 포스트 유형을 수정할... ]
# 82 : css 미디어쿼리(media <b>query</b>) 반응형 웹페이지 만들기
# [CSS의 미디어쿼리(media <b>query</b>) 를 사용하면 화면의 해상도에 따라서 페이지를 다르게 보여줄 수... (media <b>query</b>) @media (min- width:30 0px) { . myclass { width:200px; height: 150px; } } 이 형식은 미디어쿼리의... ]
# 83 : aws cloudfront 에서 <b>query</b> string 기반 cache 우회
# [아래의 매뉴얼을 보고 그대로 하면 되는데, aws 콘솔 화면에서 cloudfront <b>query</b>... <b>query</b> string 을 기반으로 캐싱을 하지 않도록 하려는 cloudfront distribution 설정 화면... ]
# 84 : Spring Data JPA에서 @<b>Query</b>사용시 Parameter
# [(라고 나는 주장한다~~~~으~~~) 기존 : @<b>Query</b>(&quot;update User set name = :name, age = :age, ssn = :ssn... 요로코롬 : @<b>Query</b>(&quot;update User set name = :#{#paramUser.name}, age = :#{#paramUser.age}, ssn... ]
# 85 : [MSSQL] 서브쿼리, 하위쿼리, Inner <b>Query</b>
# [OverIt [MSSQL] 서브쿼리, 하위쿼리, Inner <b>Query</b> 본문 DataBase/MS SQL [MSSQL] 서브쿼리, 하위쿼리, Inner <b>Query</b> YawnsDuzin 2019. 5. 23. 15:51 https://infodbbase.tistory.com/45 [MS... ]
# 86 : binlog format에 따른 <b>query</b> handling &amp; Isolation Level 선택
# [Binlog Format에 따른 <b>Query</b> Handling STATEMENT 방식으로 REPEATABLE READ Isolation Level을 사용하여... 따른 <b>query</b> handling &amp; Isolation Level 선택 (0) 2019.06.06 MySQL 내의 process 와 OS 레벨의 process... ]
# 87 : [Spring boot2-jpa] Validation failed for <b>query</b> for...
# [[Spring boot2-jpa] Validation failed for <b>query</b> for method... 에러 general java 2019. 4. 1. 16:31 spring boot2에 jpa에서 native <b>query</b> 를 사용하다가. Validation failed for <b>query</b> for method... 에러를... ]
# 88 : Candor in Supreme Court Opinions: A Skeptical <b>Query</b>
# [Sunday, June 23, 2019 Candor in Supreme Court Opinions: A Skeptical <b>Query</b> Mark Tushnet Dissenting in Franchise Tax Board v. Hyatt , Justice Breyer commented on the majority's decision... ]
# 89 : [CakePHP] CakePHP ORM의 <b>Query</b>식과 Entity, Table...
# [이 글은 CakePHP에서 데이터 베이스 접속시 사용되는 <b>Query</b>식과 Entity, Table 클래스... <b>Query</b> 식이라는 것은 그 데이터 베이스 접속시에 사용되는 쿼리를 함수적으로... ]
# 90 : usage spring data jpa with <b>query</b> dsl
# [-- dependency &lt;!-- <b>query</b> dsl dependency --&gt;&lt;dependency&gt; &lt;groupId&gt;com.querydsl&lt;/groupId&gt; &lt;artifactId&gt;querydsl-apt&lt;/artifactId&gt;&lt;/dependency&gt;&lt;dependency&gt; &lt;groupId&gt;com.querydsl&lt;/groupId... ]
# 91 : [Java강좌 - 50] JPA의 <b>Query</b> 만들기
# [이 글은 JPA의 <b>Query</b> 만들기에 대한 글입니다. JPA에서 데이터를 취득하는 방법에는... <b>Query</b> <b>query</b> = em.createNativeQuery(&quot;select * from user join info on user.id = info.id where user.id = 'TEST... ]
# 92 : [Spring, JPA] junit test 돌릴 때 hibernate <b>query</b>가...
# [junit test 돌릴 때 hibernate <b>query</b>가 어떻게 동작하는지 보고 싶을 때 <b>query</b>가 안나오는 경우 1. <b>query</b>를 노출시키지 않은 경우, application.yml or .properties 파일에 아래처럼 설정을 추가해서... ]
# 93 : 서치 엔진에서의 사용자의 의도에 따른 3 가지 <b>Query</b> 유형
# [특히 유저의 의도를 분석할 때, <b>Query</b>의 유형 을 일반적으로 3가지로 나눈다. 먼저, 1세대 <b>Query</b> 버전이라고 볼 수 있는 Navigational Search queries 가 있다. 이는, 쿼리 검색을 통해서 사용자가 원하는... ]
# 94 : Content Resolver을 이용한 <b>query</b>
# [이때 ContentResolver의 <b>query</b>() 메서드 를 이용하여 데이터를 쿼리 할 수 있는데 이때 총 5개의 파라미터가 존재하게 된다. ContentResolver : <b>query</b>(uri, projection, selection... ]
# 95 : 안드로이드 그룹 멤버 검색하기 - Group Member <b>Query</b>
# [count <b>query</b>에 대해 검색 할 필요가 있다. (그룹이름 옆에 그룹에 대한 멤버수를... Cursor cursor = mContext.getContentResolver().<b>query</b>(ContactsContract.Groups.CONTENT_SUMMARY_URI, new... ]
# 96 : [android] 안드로이드 그룹 검색 하기 - Group <b>Query</b>
# [안드로이드 그룹 검색 하기 - Group <b>Query</b> 안드로이드에서 그룹은 필수가 아닌 선택... private Cursor getGroupCursor(Context context) { Cursor cursor = context.getContentResolver().<b>query</b>(ContactsContract.Groups.... ]
# 97 : [PWC] META, Session, Mapping <b>Query</b> base
# [--//-------------------------------------------------------- --// SESSION, MAPPING의 <b>QUERY</b>... SESSION에서 <b>QUERY</b> BASE */ SESS.SUBJECT_ID , SUBJ.SUBJ_NAME , INST.SESSION_ID , SESS.TASK... ]
# 98 : flashback versions <b>query</b> &amp; flashback transaction <b>query</b>
# [flashback versions <b>query</b> &amp; flashback transaction <b>query</b> made by 도익 오늘은 맨체스터 유니이티드와 바르셀로나가 맞붙는 챔피언스리그 결승이 있는 날이다. 필자는 박지성 팬이라 맛있는... ]
# 99 : Python - <b>Query</b> String
# [쿼리스트링은 사용자가 웹 프로그램으로 입력 데이터를 전달 하는 방법이다. 쿼리스트링은 다음과 같이 form.getvalue(&quot;id&quot;)를 통해서 값을 불러 올 수 있다. 각 a태그를 누르면 HTML, CSS, JavaScript를... ]
# 100 : 페이징 쿼리(<b>QUERY</b>)
# [3가지 방법 중에 어떤 것을 사용해도 상관없다. 단, 3번이 오라클에서 공식적으로 보여주고 있는 방식이다. 1) SELECT * FROM (SELECT ROWNUM AS RNUM, T1.* FROM (SELECT * FROM... ]
